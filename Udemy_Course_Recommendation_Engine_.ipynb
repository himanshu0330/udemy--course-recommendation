# %% [markdown]
# # Content Based Recommendation System

# %% [markdown]
# ## Data => PreProcessing => Model Building => Deployement

# %% [markdown]
# ### DOWNLOAD DATASET FROM KAGGLE USING APIS

# %%
! pip install kaggle
# Out:
# Requirement already satisfied: kaggle in /usr/local/lib/python3.10/dist-packages (1.5.16)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.10/dist-packages (from kaggle) (1.16.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from kaggle) (2024.2.2)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (from kaggle) (2.8.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from kaggle) (2.31.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from kaggle) (4.66.2)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.10/dist-packages (from kaggle) (8.0.4)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.10/dist-packages (from kaggle) (2.0.7)
# Requirement already satisfied: bleach in /usr/local/lib/python3.10/dist-packages (from kaggle) (6.1.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from bleach->kaggle) (0.5.1)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.10/dist-packages (from python-slugify->kaggle) (1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->kaggle) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->kaggle) (3.6)

# %%
! mkdir ~/.kaggle

# %%
! cp kaggle.json ~/.kaggle

# %%
! kaggle datasets download -d andrewmvd/udemy-courses
# Out:
# Warning: Your Kaggle API key is readable by other users on this system! To fix this, you can run 'chmod 600 /root/.kaggle/kaggle.json'
# Downloading udemy-courses.zip to /content
# 100% 200k/200k [00:00<00:00, 559kB/s]
# 100% 200k/200k [00:00<00:00, 559kB/s]

# %%
! unzip -qq udemy-courses.zip

# %% [markdown]
# # EDA

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('/content/udemy_courses.csv')

# %%
df.head(1)
# Out:
#    course_id                        course_title  \
# 0    1070968  Ultimate Investment Banking Course
#
#                                                  url  is_paid  price  \
# 0  https://www.udemy.com/ultimate-investment-bank...     True    200
#
#    num_subscribers  num_reviews  num_lectures       level  content_duration  \
# 0             2147           23            51  All Levels               1.5
#
#     published_timestamp           subject
# 0  2017-01-18T20:58:58Z  Business Finance

# %%
df.tail(1)
# Out:
#       course_id                                       course_title  \
# 3677     297602  Using MODX CMS to Build Websites: A Beginner's...
#
#                                                     url  is_paid  price  \
# 3677  https://www.udemy.com/using-modx-cms-to-build-...     True     45
#
#       num_subscribers  num_reviews  num_lectures           level  \
# 3677              901           36            20  Beginner Level
#
#       content_duration   published_timestamp          subject
# 3677               2.0  2014-09-28T19:51:11Z  Web Development

# %%
print(df.shape)
# Out:
# (3678, 12)

# %% [markdown]
# Dropping Columns of non usage

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3678 entries, 0 to 3677
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   course_id            3678 non-null   int64
#  1   course_title         3678 non-null   object
#  2   url                  3678 non-null   object
#  3   is_paid              3678 non-null   bool
#  4   price                3678 non-null   int64
#  5   num_subscribers      3678 non-null   int64
#  6   num_reviews          3678 non-null   int64
#  7   num_lectures         3678 non-null   int64
#  8   level                3678 non-null   object
#  9   content_duration     3678 non-null   float64
#  10  published_timestamp  3678 non-null   object
#  11  subject              3678 non-null   object
# dtypes: bool(1), float64(1), int64(5), object(5)
# memory usage: 319.8+ KB

# %%
# course_id, course_title, url, subject are only of use
df = df[['course_id','course_title', 'url', 'subject']]

# %%
df.head()
# Out:
#    course_id                                       course_title  \
# 0    1070968                 Ultimate Investment Banking Course
# 1    1113822  Complete GST Course & Certification - Grow You...
# 2    1006314  Financial Modeling for Business Analysts and C...
# 3    1210588  Beginner to Pro - Financial Analysis in Excel ...
# 4    1011058       How To Maximize Your Profits Trading Options
#
#                                                  url           subject
# 0  https://www.udemy.com/ultimate-investment-bank...  Business Finance
# 1      https://www.udemy.com/goods-and-services-tax/  Business Finance
# 2  https://www.udemy.com/financial-modeling-for-b...  Business Finance
# 3  https://www.udemy.com/complete-excel-finance-c...  Business Finance
# 4  https://www.udemy.com/how-to-maximize-your-pro...  Business Finance

# %% [markdown]
# ## Handling Missing data

# %%
df.isnull().sum()
# Out:
# course_id       0
# course_title    0
# url             0
# subject         0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 6

# %%
df.drop_duplicates(inplace=True) #It will remove all the Duplicate values

# %%
df.head()
# Out:
#    course_id                                       course_title  \
# 0    1070968                 Ultimate Investment Banking Course
# 1    1113822  Complete GST Course & Certification - Grow You...
# 2    1006314  Financial Modeling for Business Analysts and C...
# 3    1210588  Beginner to Pro - Financial Analysis in Excel ...
# 4    1011058       How To Maximize Your Profits Trading Options
#
#                                                  url           subject
# 0  https://www.udemy.com/ultimate-investment-bank...  Business Finance
# 1      https://www.udemy.com/goods-and-services-tax/  Business Finance
# 2  https://www.udemy.com/financial-modeling-for-b...  Business Finance
# 3  https://www.udemy.com/complete-excel-finance-c...  Business Finance
# 4  https://www.udemy.com/how-to-maximize-your-pro...  Business Finance

# %%
df['course_title']
# Out:
# 0                      Ultimate Investment Banking Course
# 1       Complete GST Course & Certification - Grow You...
# 2       Financial Modeling for Business Analysts and C...
# 3       Beginner to Pro - Financial Analysis in Excel ...
# 4            How To Maximize Your Profits Trading Options
#                               ...
# 3673    Learn jQuery from Scratch - Master of JavaScri...
# 3674    How To Design A WordPress Website With No Codi...
# 3675                        Learn and Build using Polymer
# 3676    CSS Animations: Create Amazing Effects on Your...
# 3677    Using MODX CMS to Build Websites: A Beginner's...
# Name: course_title, Length: 3672, dtype: object

# %%
# df['course_title'] = df['course_title'].apply(lambda x:x.split())

# %%
# df['subject'] = df['subject'].apply(lambda x:x.split())

# %%
df.head()
# Out:
#    course_id                                       course_title  \
# 0    1070968            [Ultimate, Investment, Banking, Course]
# 1    1113822  [Complete, GST, Course, &, Certification, -, G...
# 2    1006314  [Financial, Modeling, for, Business, Analysts,...
# 3    1210588  [Beginner, to, Pro, -, Financial, Analysis, in...
# 4    1011058  [How, To, Maximize, Your, Profits, Trading, Op...
#
#                                                  url              subject  \
# 0  https://www.udemy.com/ultimate-investment-bank...  [Business, Finance]
# 1      https://www.udemy.com/goods-and-services-tax/  [Business, Finance]
# 2  https://www.udemy.com/financial-modeling-for-b...  [Business, Finance]
# 3  https://www.udemy.com/complete-excel-finance-c...  [Business, Finance]
# 4  https://www.udemy.com/how-to-maximize-your-pro...  [Business, Finance]
#
#                                                 tags
# 0  [Ultimate, Investment, Banking, Course, Busine...
# 1  [Complete, GST, Course, &, Certification, -, G...
# 2  [Financial, Modeling, for, Business, Analysts,...
# 3  [Beginner, to, Pro, -, Financial, Analysis, in...
# 4  [How, To, Maximize, Your, Profits, Trading, Op...

# %% [markdown]
# String Space Removing as tags can be different

# %%
df['course_title'] = df['course_title'].apply(lambda x:[i.replace(" ","") for i in x])
df['subject']=df['subject'].apply(lambda x:[i.replace(" ","") for i in x])

# %%
df.head()
# Out:
#    course_id                                       course_title  \
# 0    1070968            [Ultimate, Investment, Banking, Course]
# 1    1113822  [Complete, GST, Course, &, Certification, -, G...
# 2    1006314  [Financial, Modeling, for, Business, Analysts,...
# 3    1210588  [Beginner, to, Pro, -, Financial, Analysis, in...
# 4    1011058  [How, To, Maximize, Your, Profits, Trading, Op...
#
#                                                  url              subject  \
# 0  https://www.udemy.com/ultimate-investment-bank...  [Business, Finance]
# 1      https://www.udemy.com/goods-and-services-tax/  [Business, Finance]
# 2  https://www.udemy.com/financial-modeling-for-b...  [Business, Finance]
# 3  https://www.udemy.com/complete-excel-finance-c...  [Business, Finance]
# 4  https://www.udemy.com/how-to-maximize-your-pro...  [Business, Finance]
#
#                                                 tags
# 0  [Ultimate, Investment, Banking, Course, Busine...
# 1  [Complete, GST, Course, &, Certification, -, G...
# 2  [Financial, Modeling, for, Business, Analysts,...
# 3  [Beginner, to, Pro, -, Financial, Analysis, in...
# 4  [How, To, Maximize, Your, Profits, Trading, Op...

# %%
df['tags'] = df['course_title'] + df['subject']

# %%
df.head()
# Out:
#    course_id                                       course_title  \
# 0    1070968            [Ultimate, Investment, Banking, Course]
# 1    1113822  [Complete, GST, Course, &, Certification, -, G...
# 2    1006314  [Financial, Modeling, for, Business, Analysts,...
# 3    1210588  [Beginner, to, Pro, -, Financial, Analysis, in...
# 4    1011058  [How, To, Maximize, Your, Profits, Trading, Op...
#
#                                                  url              subject  \
# 0  https://www.udemy.com/ultimate-investment-bank...  [Business, Finance]
# 1      https://www.udemy.com/goods-and-services-tax/  [Business, Finance]
# 2  https://www.udemy.com/financial-modeling-for-b...  [Business, Finance]
# 3  https://www.udemy.com/complete-excel-finance-c...  [Business, Finance]
# 4  https://www.udemy.com/how-to-maximize-your-pro...  [Business, Finance]
#
#                                                 tags
# 0  [Ultimate, Investment, Banking, Course, Busine...
# 1  [Complete, GST, Course, &, Certification, -, G...
# 2  [Financial, Modeling, for, Business, Analysts,...
# 3  [Beginner, to, Pro, -, Financial, Analysis, in...
# 4  [How, To, Maximize, Your, Profits, Trading, Op...

# %%
new_df = df[['course_title', 'subject','tags']]

# %%
new_df
# Out:
#                                            course_title              subject  \
# 0               [Ultimate, Investment, Banking, Course]  [Business, Finance]
# 1     [Complete, GST, Course, &, Certification, -, G...  [Business, Finance]
# 2     [Financial, Modeling, for, Business, Analysts,...  [Business, Finance]
# 3     [Beginner, to, Pro, -, Financial, Analysis, in...  [Business, Finance]
# 4     [How, To, Maximize, Your, Profits, Trading, Op...  [Business, Finance]
# ...                                                 ...                  ...
# 3673  [Learn, jQuery, from, Scratch, -, Master, of, ...   [Web, Development]
# 3674  [How, To, Design, A, WordPress, Website, With,...   [Web, Development]
# 3675                [Learn, and, Build, using, Polymer]   [Web, Development]
# 3676  [CSS, Animations:, Create, Amazing, Effects, o...   [Web, Development]
# 3677  [Using, MODX, CMS, to, Build, Websites:, A, Be...   [Web, Development]
#
#                                                    tags
# 0     [Ultimate, Investment, Banking, Course, Busine...
# 1     [Complete, GST, Course, &, Certification, -, G...
# 2     [Financial, Modeling, for, Business, Analysts,...
# 3     [Beginner, to, Pro, -, Financial, Analysis, in...
# 4     [How, To, Maximize, Your, Profits, Trading, Op...
# ...                                                 ...
# 3673  [Learn, jQuery, from, Scratch, -, Master, of, ...
# 3674  [How, To, Design, A, WordPress, Website, With,...
# 3675  [Learn, and, Build, using, Polymer, Web, Devel...
# 3676  [CSS, Animations:, Create, Amazing, Effects, o...
# 3677  [Using, MODX, CMS, to, Build, Websites:, A, Be...
#
# [3672 rows x 3 columns]

# %%
new_df['tags'] = new_df['tags'].apply(lambda x:" ".join(x))
# Out:
# <ipython-input-87-ad44e9ca1347>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['tags'] = new_df['tags'].apply(lambda x:" ".join(x))

# %%
new_df.head()
# Out:
#                                         course_title              subject  \
# 0            [Ultimate, Investment, Banking, Course]  [Business, Finance]
# 1  [Complete, GST, Course, &, Certification, -, G...  [Business, Finance]
# 2  [Financial, Modeling, for, Business, Analysts,...  [Business, Finance]
# 3  [Beginner, to, Pro, -, Financial, Analysis, in...  [Business, Finance]
# 4  [How, To, Maximize, Your, Profits, Trading, Op...  [Business, Finance]
#
#                                                 tags
# 0  Ultimate Investment Banking Course Business Fi...
# 1  Complete GST Course & Certification - Grow You...
# 2  Financial Modeling for Business Analysts and C...
# 3  Beginner to Pro - Financial Analysis in Excel ...
# 4  How To Maximize Your Profits Trading Options B...

# %%
new_df['tags'][0]
# Out:
# 'Ultimate Investment Banking Course Business Finance'

# %% [markdown]
# Suggested to lowercase whole data

# %%
new_df['tags']= new_df['tags'].apply(lambda x:x.lower())
# Out:
# <ipython-input-90-6f81e3301db6>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['tags']= new_df['tags'].apply(lambda x:x.lower())

# %%
new_df.head()
# Out:
#                                         course_title              subject  \
# 0            [Ultimate, Investment, Banking, Course]  [Business, Finance]
# 1  [Complete, GST, Course, &, Certification, -, G...  [Business, Finance]
# 2  [Financial, Modeling, for, Business, Analysts,...  [Business, Finance]
# 3  [Beginner, to, Pro, -, Financial, Analysis, in...  [Business, Finance]
# 4  [How, To, Maximize, Your, Profits, Trading, Op...  [Business, Finance]
#
#                                                 tags
# 0  ultimate investment banking course business fi...
# 1  complete gst course & certification - grow you...
# 2  financial modeling for business analysts and c...
# 3  beginner to pro - financial analysis in excel ...
# 4  how to maximize your profits trading options b...

# %% [markdown]
# # Text_Vectorization

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer(max_features=5000,stop_words='english')

# %%
vectors = cv.fit_transform(new_df['tags']).toarray()

# %%
vectors[0]
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
# new_df['tags'][0]

# %%
cv.get_feature_names_out()
# Out:
# array(['00005', '001', '01', ..., '１週間でホームページのトップ画像を製作できるようになる画像製作講座',
#        '６時間でインターバンク市場を攻略', '７日でマスター'], dtype=object)

# %% [markdown]
# ## Stemming - Basically finding the Root Word

# %%
# The idea is
# ['loved', 'loving', 'love'] => ['love', 'love', 'love']

# %%
! pip install nltk
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.8.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk) (2023.12.25)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk) (4.66.2)

# %%
from nltk.stem.porter import PorterStemmer
ps = PorterStemmer()

# %%
def stem(text):
  y = []
  for i in text.split():
    y.append(ps.stem(i))
  return " ".join(y)

# %%
 new_df['tags'] = new_df['tags'].apply(stem)
# Out:
# <ipython-input-101-be18a4346d89>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['tags'] = new_df['tags'].apply(stem)

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer(max_features=5000,stop_words='english')

# %%
vectors = cv.fit_transform(new_df['tags']).toarray()

# %%
vectors[0]
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
cv.get_feature_names_out()
# Out:
# array(['00005', '001', '01', ..., '１週間でホームページのトップ画像を製作できるようになる画像製作講座',
#        '６時間でインターバンク市場を攻略', '７日でマスター'], dtype=object)

# %% [markdown]
# ## Now Using Cosine Similarity to find the Distance between two vectors

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
similarity = cosine_similarity(vectors)

# %%
similarity[0] # Printing the Similairty Matrix for 0th Vector
# Out:
# array([1.        , 0.40824829, 0.40824829, ..., 0.        , 0.        ,
#        0.        ])

# %%
new_df[new_df['course_title'] == 'ultim invest bank cours busi financ']
# Out:
# Empty DataFrame
# Columns: [course_title, subject, tags]
# Index: []

# %%
# Driver Method
def recommend(course):
  course_index = new_df[new_df['course_title'] == course].index[0]
  distances = similarity[course_index]
  courses_list=sorted(list(enumerate(distances)),reverse=True,key=lambda x:x[1])[1:6]

  for i in courses_list:
    # print(new_df.iloc[i[0]].course_title)
    print(i[0])

# %%
recommend('ultim invest bank cours busi financ')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-111-9874564ffaf1> in <cell line: 1>()
# ----> 1 recommend('ultim invest bank cours busi financ')
#
# <ipython-input-110-aaa8a3fb824f> in recommend(course)
#       1 # Driver Method
#       2 def recommend(course):
# ----> 3   course_index = new_df[new_df['course_title'] == course].index[0]
#       4   distances = similarity[course_index]
#       5   courses_list=sorted(list(enumerate(distances)),reverse=True,key=lambda x:x[1])[1:6]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in __getitem__(self, key)
#    5173             # GH#44051 exclude bool, which would return a 2d ndarray
#    5174             key = com.cast_scalar_indexer(key)
# -> 5175             return getitem(key)
#    5176
#    5177         if isinstance(key, slice):
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %% [markdown]
# ## Connection Code

# %%
# import pickle

# %%
# pickle.dump(new_df,open('movies.pkl', 'wb'))
# pickle.dump(new_df.to_dict(),open('course_dict.pkl', 'wb'))

# %%
# dumping that similarity array if each vector
# pickle.dump(similarity,open('similarity.pkl','wb'))
